# %% [markdown]
# # Retrieval Augmented Generation
# * another method of connecting a large language model with an external datasource
#     * function calling is connecting to other peoples data with APIs
#     * RAG connects to your own database
# * usually focused on private or unorganized data
#     * Over 95% of the world’s data is private (personal, company, etc.)
# * supplies the model with the additional relevant information from the datasource within the context of the input prompt
#
# ## 3 Steps of RAG
# 1. Indexing - formatting the database so data can be retrieved based on the user's natural language response
#     * usually done once initially with any updates necessary
#     * the retrieval function is to be applied to the indexed database
#     * we index a document by converting it into a numerical representation which we call embeddings (similar to tokenization)
#         * **Embeddings** - a vector of floats that stores semantic similarity in a multidimensional space
#         * There is a context limit for embeddings - longer documents get split into chunks
#         * The user prompt normally gets converted into an embedding to search the vector database (the storage of all the document chunk embeddings)
# 2. Retrieval - finding the relevant data in the indexed database using a function to then pass to the model for generation
#     * the 'retrieval' of the supplemental data
#     * **Cosine Similarity** - the distance between two vectors in a multidimensional space (represents relatedness)
#     * **K-Nearest Neighbor Search (kNN)** - one of the most common retrieval functions
#         * finds the lowest cosine similarity values between the prompt embedding and the dataset chunk embeddings
#         * K - the number of nearest neighbors that will be retrieved
#             * Higher k means the increased probability that the info needed is provided for generation
# 3. Generation - taking the retrieved data and the initial user prompt and prompting the model to get a factual response
#     * This is where we actually prompt the model

# %% [markdown]
# ## Embedding Example
# Lets see what an embedding looks like.
#
#
# Lets embed a possible user prompt that this chatbot would recieve.

# %%
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv
import os

load_dotenv("C:/Users/Patrick/Desktop/PROJECTS/Python Lesson Plan/AI_CLASS_7/api.env")
api_key = os.getenv("OPENAI_API_KEY")

prompt = "What is the policy on PTO?"
embeddings = OpenAIEmbeddings(api_key=api_key, model="text-embedding-3-large") # , dimensions=1024
query_result = embeddings.embed_query(prompt)
print(f"{query_result}\nLength of embedding: {len(query_result)}")
# Out:
# [-0.06600009649991989, -0.006616381462663412, -0.018194159492850304, 4.1736100683920085e-05, -7.546420965809375e-05, 0.03362645208835602, -0.018265342339873314, 0.02776104211807251, -0.01790943183004856, 0.03584733605384827, 0.044616978615522385, -0.01354596484452486, 0.0026159442495554686, -0.000760759343393147, 0.015859384089708328, 0.0413425974547863, -0.04493017867207527, 0.0401182658970356, 0.0139089934527874, -0.008790996856987476, 0.021397357806563377, 0.006598586216568947, -0.020101841539144516, 0.019817113876342773, 0.034623000770807266, 0.029141975566744804, 0.02722005732357502, 0.001170946517959237, -0.0012688220012933016, 0.0359327532351017, -0.018678197637200356, 0.032259754836559296, 0.037925854325294495, -0.011232544668018818, -0.030038870871067047, 0.0005957057001069188, 0.0568603090941906, -0.035163987427949905, -0.025654049590229988, 0.003843836486339569, -0.019162237644195557, -0.041570380330085754, 0.01708371751010418, 0.0036
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: langchain_community in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (0.2.7)
# Requirement already satisfied: tiktoken in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (0.7.0)
# Requirement already satisfied: langchain-openai in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (0.1.15)
# Requirement already satisfied: langchainhub in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (0.1.20)
# Requirement already satisfied: chromadb in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (0.5.4)
# Requirement already satisfied: langchain in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (0.2.7)
# Collecting beautifulsoup4 (from bs4)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from langchain_community) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from langchain_community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.12 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from langchain_community) (0.2.13)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from langchain_community) (0.1.85)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from langchain_community) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from tiktoken) (2024.5.10)
# Requirement already satisfied: openai<2.0.0,>=1.32.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from langchain-openai) (1.35.13)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from langchainhub) (23.2)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from langchainhub) (2.32.0.20240712)
# Requirement already satisfied: build>=1.0.3 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (2.8.2)
# Requirement already satisfied: chroma-hnswlib==0.7.5 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.7.5)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.111.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.1)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.10.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.18.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.66.2)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.63.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (30.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (3.10.6)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: pyproject_hooks in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: colorama in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.4)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from fastapi>=0.95.2->chromadb) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.9)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from fastapi>=0.95.2->chromadb) (2.2.0)
# Requirement already satisfied: anyio in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (4.3.0)
# Requirement already satisfied: certifi in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.4)
# Requirement already satisfied: idna in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (3.6)
# Requirement already satisfied: sniffio in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\patrick\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\patrick\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.30.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.3.0,>=0.2.12->langchain_community) (1.33)
# Requirement already satisfied: coloredlogs in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.3)
# Requirement already satisfied: sympy in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (1.9.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.1.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.46b0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (69.5.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=1.9->chromadb) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.23.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->bs4)
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb) (2.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.3.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.12->langchain_community) (3.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\patrick\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.18.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\patrick\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.12.3 bs4-0.0.2 soupsieve-2.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Imports
# * import everything necessary for the program
#     * bs4 - beautifulsoup - a helpful webscraper
#     * langchain.hub - used to pull a helpful RAG prompt
#     * langchain.text_splitter - chunks the documents before embedding
#     * langchain_community.document_loaders - loads the website as a document
#     * langchain_community.vectorstores - connects the open source vector storage we are using (ChromadB)
#     * StrOutputParser - basic string output parser (more info in langchain notebook)
#     * RunnablePassthrough - a placeholder for the user prompt in the RAG chain
#     * ChatOpenAI - the OpenAI chat completions API client through langchain
#     * OpenAIEmbeddings - the OpenAI embeddings API client through langchain

# %%
import bs4
from langchain import hub
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# ## Indexing
# * We use beautifulsoup and the webbaseloader to get the content from a website and convert it into a document that can be embedded

# %%
# Load Documents
loader = WebBaseLoader(
    web_paths=("https://lilianweng.github.io/posts/2023-06-23-agent/",),
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=("post-content", "post-title", "post-header")
        )
    ),
)
docs = loader.load()

# Split the documents into chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(docs)

# Lets check out the chunks
print(f'Length of chunked document: {len(splits)}\n')
print(f'First chunk of document: \n\n{splits[0]}\n')
print(f'Last chunk of document: \n\n{splits[-1]}\n')
# Out:
# Length of chunked document: 66
#
# First chunk of document:
#
# page_content='LLM Powered Autonomous Agents
#
# Date: June 23, 2023  |  Estimated Reading Time: 31 min  |  Author: Lilian Weng
#
#
# Building agents with LLM (large language model) as its core controller is a cool concept. Several proof-of-concepts demos, such as AutoGPT, GPT-Engineer and BabyAGI, serve as inspiring examples. The potentiality of LLM extends beyond generating well-written copies, stories, essays and programs; it can be framed as a powerful general problem solver.
# Agent System Overview#
# In a LLM-powered autonomous agent system, LLM functions as the agent’s brain, complemented by several key components:
#
# Planning
#
# Subgoal and decomposition: The agent breaks down large tasks into smaller, manageable subgoals, enabling efficient handling of complex tasks.
# Reflection and refinement: The agent can do self-criticism and self-reflection over past actions, learn from mistakes and refine them for future steps, thereby improving the quality of final results.
#
#
# Memory' metadata={'source': 'https://lilianweng.github.io/posts/2023-06-23-agent/'}
#
# Last chunk of document:
#
# page_content='[13] Schick et al. “Toolformer: Language Models Can Teach Themselves to Use Tools.” arXiv preprint arXiv:2302.04761 (2023).
# [14] Weaviate Blog. Why is Vector Search so fast? Sep 13, 2022.
# [15] Li et al. “API-Bank: A Benchmark for Tool-Augmented LLMs” arXiv preprint arXiv:2304.08244 (2023).
# [16] Shen et al. “HuggingGPT: Solving AI Tasks with ChatGPT and its Friends in HuggingFace” arXiv preprint arXiv:2303.17580 (2023).
# [17] Bran et al. “ChemCrow: Augmenting large-language models with chemistry tools.” arXiv preprint arXiv:2304.05376 (2023).
# [18] Boiko et al. “Emergent autonomous scientific research capabilities of large language models.” arXiv preprint arXiv:2304.05332 (2023).
# [19] Joon Sung Park, et al. “Generative Agents: Interactive Simulacra of Human Behavior.” arXiv preprint arXiv:2304.03442 (2023).
# [20] AutoGPT. https://github.com/Significant-Gravitas/Auto-GPT
# [21] GPT-Engineer. https://github.com/AntonOsika/gpt-engineer' metadata={'source': 'https://lilianweng.github.io/posts/2023-06-23-agent/'}

# %% [markdown]
# ## Retrieval
# * ChromadB has a built-in retriever function - https://api.python.langchain.com/en/latest/vectorstores/langchain_community.vectorstores.chroma.Chroma.html#langchain_community.vectorstores.chroma.Chroma.as_retriever
# * Lets build the chain and connect the retriever to a prompt template that incorporates the initial user prompt and the retrieved context

# %%
# Create a vectorstore from the embedded chunks
vectorstore = Chroma.from_documents(documents=splits, embedding=OpenAIEmbeddings())
# Create the retriever from the vectorstore
retriever = vectorstore.as_retriever()
print(retriever)
# Out:
# tags=['Chroma', 'OpenAIEmbeddings'] vectorstore=<langchain_community.vectorstores.chroma.Chroma object at 0x000001E5F3B07290>

# %%
# Prompt Template
prompt = hub.pull("rlm/rag-prompt")
print(prompt.messages[0].prompt.template)
# Out:
# You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
# Question: {question}
# Context: {context}
# Answer:

# %% [markdown]
# ## Generation
# * Create the chain to connect all the parts of the RAG system

# %%
# Chat Completions API Client
llm = ChatOpenAI(api_key=api_key, model_name="gpt-3.5-turbo", temperature=0)

# Post-processing where we combine the retrieved chunks into a single document
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# Create the chain
rag_chain = (
    # The retriever will retrieve the relevant documents based on the prompt passed through the .invoke() function
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    # The retrieved documents and user prompt will be passed to the prompt template
    | prompt
    # The prompt template will be passed to the language model
    | llm
    # The output from the language model will be parsed into a string
    | StrOutputParser()
)

# %% [markdown]
# ## Test the RAG chain

# %%
# Question
rag_chain.invoke("What is Task Decomposition?")
# Out:
# "A reflection mechanism is a framework that equips agents with dynamic memory and self-reflection capabilities to improve reasoning skills. It involves showing examples to the agent for guiding future changes in the plan and adding reflections into the agent's working memory. The agent computes a heuristic after each action and may decide to reset the environment based on the self-reflection results."
